# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Cinética de primer orden
# ## A --> B

# %%
#dar valor a la conc de A, B, dty k1
A=1.0
B=0
k1=0.1
dt=0.1
t=0
x=[]
yA=[]
yB=[]
#usar ciclo while para asegurar que el tiempo va aumentando
while t<100:
    x.append(t) #append para añadir objetos a la lista vacia creada
    yA.append(A)
    yB.append(B)
    dA=-k1*A*dt
    dB=+k1*A*dt
    A+=dA
    B+=dB
    t+=dt
print(yA)
# Out:
# [1.0, 0.99, 0.9801, 0.970299, 0.9605960100000001, 0.9509900499, 0.941480149401, 0.93206534790699, 0.9227446944279202, 0.9135172474836409, 0.9043820750088045, 0.8953382542587165, 0.8863848717161293, 0.8775210229989681, 0.8687458127689783, 0.8600583546412885, 0.8514577710948756, 0.8429431933839269, 0.8345137614500876, 0.8261686238355868, 0.8179069375972309, 0.8097278682212585, 0.801630589539046, 0.7936142836436555, 0.785678140807219, 0.7778213593991468, 0.7700431458051553, 0.7623427143471038, 0.7547192872036327, 0.7471720943315964, 0.7397003733882804, 0.7323033696543976, 0.7249803359578536, 0.717730532598275, 0.7105532272722923, 0.7034476949995694, 0.6964132180495737, 0.6894490858690779, 0.6825545950103872, 0.6757290490602833, 0.6689717585696805, 0.6622820409839837, 0.6556592205741438, 0.6491026283684024, 0.6426116020847183, 0.6361854860638712, 0.6298236312032325, 0.6235253948912002, 0.6172901409422882, 0.6111172395328653, 0.6050060671375367, 0.5989560064661613, 0.5929664464014996, 0.5
# ...

# %%
plt.plot(x,yA)
plt.plot(x,yB)
plt.xlabel("t(min)")
plt.ylabel("Concentracion")
plt.title("Cinetica de primer orden")
plt.show()

# %% [markdown]
# ## Cinética secuencial
# ## A --> B
# ## B --> C

# %%
A=1.0
B=0
C=0
k1=0.1
k2=0.1
dt=0.1
t=0
x=[]
yA=[]
yB=[]
yC=[]
while t<100:
    x.append(t) #append para añadir objetos a la lista vacia creada
    yA.append(A)
    yB.append(B)
    yC.append(C)
    dA=-k1*A*dt
    dB=-k2*B*dt+k1*A*dt
    dC=k2*B*dt
    A+=dA
    B+=dB
    C+=dC
    t+=dt
print(yC)
# Out:
# [0, 0.0, 0.00010000000000000003, 0.0002980000000000001, 0.0005920300000000001, 0.0009801496000000002, 0.0014604476050000003, 0.0020310416349400007, 0.0026900777395207007, 0.0034357300178462927, 0.004266200242831421, 0.005179717490315062, 0.006174537772824748, 0.007248943677935208, 0.008401244011166176, 0.009629773443364732, 0.0109328921625182, 0.012308985529944262, 0.01375646374080555, 0.01527376148889662, 0.016859337635651787, 0.018511674883322962, 0.02022927945227715, 0.02201068076236392, 0.023854431118303727, 0.0257591053990485, 0.02772330075106655, 0.02974563628550433, 0.03182475277917825, 0.03395931237935014, 0.03614799831224068, 0.03838951459523547, 0.04068258575273914, 0.043025956535633215, 0.045418391644294134, 0.04785867545512827, 0.0503456117505813, 0.05287802345257975, 0.055454752359363174, 0.058074658885665674, 0.06073662180620618, 0.06343953800244731, 0.066182322212583, 0.06896390678471573, 0.07178324143318454, 0.07463929299800551, 0.07753104520738674, 0.0804574984432805
# ...

# %%
plt.plot(x,yA)
plt.plot(x,yB)
plt.plot(x,yC)
plt.xlabel("t(min)")
plt.ylabel("Concentracion")
plt.title("Cinetica secuencial")
plt.show()

# %% [markdown]
# ## Equilibrio de primer orden
# ## A < -- > B

# %%
#lo mismo que en la primera, solo se cambian las formulas
A=1.0
B=0
k1=0.1
k2=0.2
dt=0.1
t=0
x=[]
yA=[]
yB=[]

while t<100:
    x.append(t) 
    yA.append(A)
    yB.append(B)
    dA=-k1*A*dt+k2*B*dt
    dB=+k1*A*dt-k2*B*dt
    A+=dA
    B+=dB
    t+=dt

# %%
plt.plot(x,yA)
plt.plot(x,yB)
plt.xlabel("t(min)")
plt.ylabel("Concentracion")
plt.title("Equilibrio")
plt.show()

# %% [markdown]
# ## Cinetica de segundo orden
# ## A +A < -- > B

# %%
A=1.0
B=0
k1=0.1
dt=0.1 #para calculos mas exactos se disminuye el dt
t=0
x=[]
yA=[]
yB=[]

while t<100:
    x.append(t) 
    yA.append(A)
    yB.append(B)
    dA=-k1*A*A*dt
    dB=+k1*A*A*dt
    A+=dA
    B+=dB
    t+=dt
plt.plot(x,yA)
plt.plot(x,yB)
plt.xlabel("t(min)")
plt.ylabel("Concentracion")
plt.title("Cinetica de segundo orden")
plt.show()
